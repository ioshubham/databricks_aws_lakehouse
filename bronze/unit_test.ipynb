# %%
# %sql
select count(*) from databricks_aws_lakehouse.bronze.bz_superstore

# %%
# %sql
drop table databricks_aws_lakehouse.bronze.bz_superstore

# %%
spark.sql("DESCRIBE HISTORY databricks_aws_lakehouse.bronze.bz_superstore").show(10, False)

# %%
dbutils.fs.ls("dbfs:/FileStore/superstore/raw/")

# %%
dbutils.fs.ls("/Workspace/databricks_aws_lakehouse/sample_data/SampleSuperstore.csv")

# %%
# %sql
select * from databricks_aws_lakehouse.bronze.bz_superstore LIMIT 5
