# %%
# %sql
select * from databricks_aws_lakehouse.silver.silver_enr

# %%
# %sql
select * from databricks_aws_lakehouse.gold.gold_sales_aggregate

# %%
# %sql
select count(*) from databricks_aws_lakehouse.gold.gold_city_sales

# %%
# %sql
select * from databricks_aws_lakehouse.gold.gold_category_sales limit 5;

# %%
# %sql
select * from databricks_aws_lakehouse.gold.gold_city_sales limit 5;

# %%
# %sql
select * from databricks_aws_lakehouse.gold.gold_region_sales limit 5;

# %%
# %sql
select * from databricks_aws_lakehouse.gold.gold_sales_aggregate limit 5;
